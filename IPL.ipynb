# %%
import pandas as pd

# %%
df=pd.read_csv("IPL dataset1 (CSBS-2023).csv")

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0         1   Abdulla, YA    2  ...         2009      50000      50000
# 1         2  Abdur Razzak    2  ...         2008      50000      50000
# 2         3   Agarkar, AB    2  ...         2008     200000     350000
# 3         4     Ashwin, R    1  ...         2011     100000     850000
# 4         5  Badrinath, S    2  ...         2011     100000     800000
# ..      ...           ...  ...  ...          ...        ...        ...
# 125     126     Yadav, AS    2  ...         2010      50000     750000
# 126     127   Younis Khan    2  ...         2008     225000     225000
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [130 rows x 26 columns]

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2  ...         2009      50000      50000
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 125     126     Yadav, AS    2  ...         2010      50000     750000
# 126     127   Younis Khan    2  ...         2008     225000     225000
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [5 rows x 26 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_columns',7)

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0         1   Abdulla, YA    2  ...         2009      50000      50000
# 1         2  Abdur Razzak    2  ...         2008      50000      50000
# 2         3   Agarkar, AB    2  ...         2008     200000     350000
# 3         4     Ashwin, R    1  ...         2011     100000     850000
# 4         5  Badrinath, S    2  ...         2011     100000     800000
# ..      ...           ...  ...  ...          ...        ...        ...
# 125     126     Yadav, AS    2  ...         2010      50000     750000
# 126     127   Younis Khan    2  ...         2008     225000     225000
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [130 rows x 26 columns]

# %%
df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1    Abdulla, YA    2  ...         2009      50000      50000
# 1       2   Abdur Razzak    2  ...         2008      50000      50000
# 2       3    Agarkar, AB    2  ...         2008     200000     350000
# 3       4      Ashwin, R    1  ...         2011     100000     850000
# 4       5   Badrinath, S    2  ...         2011     100000     800000
# 5       6     Bailey, GJ    2  ...         2009      50000      50000
# 6       7      Balaji, L    2  ...         2011     100000     500000
# 7       8  Bollinger, DE    2  ...         2011     200000     700000
# 8       9       Botha, J    2  ...         2011     200000     950000
# 9      10    Boucher, MV    2  ...         2008     200000     450000
#
# [10 rows x 26 columns]

# %%
df.tail(3)
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [3 rows x 26 columns]

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING_ROLE',
#  'T_RUNS',
#  'T_WKTS',
#  'ODI_RUNS-S',
#  'ODI_SR_B',
#  'ODI_WKTS',
#  'ODI_SR_BL',
#  'CAPTAINCY_EXP',
#  'RUNS_S',
#  'HS',
#  'AVE',
#  'SR_B',
#  'SIXERS',
#  'RUNS_C',
#  'WKTS',
#  'AVE_BL',
#  'ECON',
#  'SR_BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.head().transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING_ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T_RUNS                   0           214          571        284            63
# T_WKTS                   0            18           58         31             0
# ODI_RUNS-S               0           657         1269        241            79
# ODI_SR_B               0.0         71.41        80.62      84.56         45.93
# ODI_WKTS                 0           185          288         51             0
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING_ROLE   130 non-null    object
#  6   T_RUNS         130 non-null    int64
#  7   T_WKTS         130 non-null    int64
#  8   ODI_RUNS-S     130 non-null    int64
#  9   ODI_SR_B       130 non-null    float64
#  10  ODI_WKTS       130 non-null    int64
#  11  ODI_SR_BL      130 non-null    float64
#  12  CAPTAINCY_EXP  130 non-null    int64
#  13  RUNS_S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR_B           130 non-null    float64
# ...

# %%
df[0:6]
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2  ...         2009      50000      50000
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
# 5       6    Bailey, GJ    2  ...         2009      50000      50000
#
# [6 rows x 26 columns]

# %%
df['PLAYER NAME'][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
df[['PLAYER NAME','SOLD PRICE']][0:5]
# Out:
#     PLAYER NAME  SOLD PRICE
# 0   Abdulla, YA       50000
# 1  Abdur Razzak       50000
# 2   Agarkar, AB      350000
# 3     Ashwin, R      850000
# 4  Badrinath, S      800000

# %%
df.iloc[0:3,0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM
# 0       1   Abdulla, YA    2      SA  KXIP
# 1       2  Abdur Razzak    2     BAN   RCB
# 2       3   Agarkar, AB    2     IND   KKR

# %%
df.COUNTRY.value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
df.AGE.value_counts()
# Out:
# AGE
# 2    86
# 3    28
# 1    16
# Name: count, dtype: int64

# %%
df.COUNTRY.value_counts(normalize=True)*100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
df.AGE.value_counts(normalize=True)*100
# Out:
# AGE
# 2    66.153846
# 3    21.538462
# 1    12.307692
# Name: proportion, dtype: float64

# %%
df.HS.value_counts(normalize=True)*100
# Out:
# HS
# 3      5.384615
# 71     3.846154
# 16     3.846154
# 11     3.076923
# 15     3.076923
#          ...
# 27     0.769231
# 65     0.769231
# 158    0.769231
# 47     0.769231
# 66     0.769231
# Name: proportion, Length: 73, dtype: float64

# %%
round(df.COUNTRY.value_counts(normalize=True)*100,3)
# Out:
# COUNTRY
# IND    40.769
# AUS    16.923
# SA     12.308
# SL      9.231
# PAK     6.923
# NZ      5.385
# WI      4.615
# ENG     2.308
# BAN     0.769
# ZIM     0.769
# Name: proportion, dtype: float64

# %%
pd.crosstab(df['AGE'],df['PLAYING_ROLE'])
# Out:
# PLAYING_ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
df.COUNTRY.value_counts().transpose()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
df[['PLAYER NAME','SOLD PRICE']][0:5]
# Out:
#     PLAYER NAME  SOLD PRICE
# 0   Abdulla, YA       50000
# 1  Abdur Razzak       50000
# 2   Agarkar, AB      350000
# 3     Ashwin, R      850000
# 4  Badrinath, S      800000

# %%
df[['PLAYER NAME','SOLD PRICE']][0:5].transpose()
# Out:
#                        0             1            2          3             4
# PLAYER NAME  Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# SOLD PRICE         50000         50000       350000     850000        800000

# %%
df.iloc[0:3,0:5].transpose()
# Out:
#                        0             1            2
# Sl.NO.                 1             2            3
# PLAYER NAME  Abdulla, YA  Abdur Razzak  Agarkar, AB
# AGE                    2             2            2
# COUNTRY               SA           BAN          IND
# TEAM                KXIP           RCB          KKR

# %%
df.iloc[0:3,0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM
# 0       1   Abdulla, YA    2      SA  KXIP
# 1       2  Abdur Razzak    2     BAN   RCB
# 2       3   Agarkar, AB    2     IND   KKR

# %%
df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2  ...         2009      50000      50000
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
#
# [5 rows x 26 columns]

# %%
df['premium']=df['SOLD PRICE']-df['BASE PRICE']

# %%
df['premium'][0:5]
# Out:
# 0         0
# 1         0
# 2    150000
# 3    750000
# 4    700000
# Name: premium, dtype: int64

# %%
df[['SOLD PRICE','BASE PRICE','premium']][0:5]
# Out:
#    SOLD PRICE  BASE PRICE  premium
# 0       50000       50000        0
# 1       50000       50000        0
# 2      350000      200000   150000
# 3      850000      100000   750000
# 4      800000      100000   700000

# %%
df[['PLAYER NAME','AGE','premium']].sort_values('premium',ascending=False)[0:5]
# Out:
#        PLAYER NAME  AGE  premium
# 50        Kohli, V    1  1650000
# 113     Tiwary, SS    1  1500000
# 127   Yuvraj Singh    2  1400000
# 111  Tendulkar, SR    3  1400000
# 93       Sehwag, V    2  1400000

# %%
df[['PLAYER NAME','AGE','premium']].sort_values('premium',ascending=True)[0:5]
# Out:
#         PLAYER NAME  AGE  premium
# 0       Abdulla, YA    2        0
# 40        Jaffer, W    2        0
# 45     Kamran Akmal    2        0
# 49       Katich, SM    3        0
# 58  Mascarenhas, AD    2        0

# %%
df.groupby('premium')['SOLD PRICE'].mean()
# Out:
# premium
# 0          1.662500e+05
# 4000       2.400000e+04
# 10000      1.100000e+05
# 20000      1.700000e+05
# 30000      6.500000e+04
# 40000      1.400000e+05
# 45000      9.500000e+04
# 60000      1.600000e+05
# 65000      4.000000e+05
# 75000      2.250000e+05
# 100000     3.500000e+05
# 125000     2.750000e+05
# 150000     3.562500e+05
# 160000     2.600000e+05
# 170000     2.700000e+05
# 175000     3.375000e+05
# 190000     2.400000e+05
# 200000     6.100000e+05
# 225000     4.250000e+05
# 240000     2.900000e+05
# 250000     4.666667e+05
# 275000     3.875000e+05
# 300000     5.000000e+05
# 325000     5.500000e+05
# 350000     5.750000e+05
# 375000     5.125000e+05
# 400000     5.666667e+05
# 425000     6.375000e+05
# 450000     6.750000e+05
# 475000     6.750000e+05
# 500000     7.000000e+05
# 505000     7.250000e+05
# 525000     6.583333e+05
# 550000     7.187500e+05
# 575000     6.750000e+05
# 600000     9.187500e+05
# 650000     9.000000e+05
# 675000     8.875000e+05
# ...

# %%
df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
df.groupby('AGE')['BASE PRICE'].max()
# Out:
# AGE
# 1     300000
# 2    1350000
# 3     450000
# Name: BASE PRICE, dtype: int64

# %%
df.groupby('premium')['SOLD PRICE'].mean().reset_index()
# Out:
#     premium    SOLD PRICE
# 0         0  1.662500e+05
# 1      4000  2.400000e+04
# 2     10000  1.100000e+05
# 3     20000  1.700000e+05
# 4     30000  6.500000e+04
# 5     40000  1.400000e+05
# 6     45000  9.500000e+04
# 7     60000  1.600000e+05
# 8     65000  4.000000e+05
# 9     75000  2.250000e+05
# 10   100000  3.500000e+05
# 11   125000  2.750000e+05
# 12   150000  3.562500e+05
# 13   160000  2.600000e+05
# 14   170000  2.700000e+05
# 15   175000  3.375000e+05
# 16   190000  2.400000e+05
# 17   200000  6.100000e+05
# 18   225000  4.250000e+05
# 19   240000  2.900000e+05
# 20   250000  4.666667e+05
# 21   275000  3.875000e+05
# 22   300000  5.000000e+05
# 23   325000  5.500000e+05
# 24   350000  5.750000e+05
# 25   375000  5.125000e+05
# 26   400000  5.666667e+05
# 27   425000  6.375000e+05
# 28   450000  6.750000e+05
# 29   475000  6.750000e+05
# 30   500000  7.000000e+05
# 31   505000  7.250000e+05
# 32   525000  6.583333e+05
# 33   550000  7.187500e+05
# ...

# %%
df.groupby('AGE')['SOLD PRICE'].mean().reset_index()
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
df.groupby('AGE')['SOLD PRICE'].max().reset_index()
# Out:
#    AGE  SOLD PRICE
# 0    1     1800000
# 1    2     1800000
# 2    3     1800000

# %%
df.groupby('AGE')['SOLD PRICE'].min().reset_index()
# Out:
#    AGE  SOLD PRICE
# 0    1       24000
# 1    2       20000
# 2    3      100000

# %%
df.groupby('AGE')['SOLD PRICE'].min()
# Out:
# AGE
# 1     24000
# 2     20000
# 3    100000
# Name: SOLD PRICE, dtype: int64

# %%
sage=df.groupby('AGE')['SOLD PRICE'].mean()

# %%
sage
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
print(sage)
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
role=df.groupby(['AGE','PLAYING_ROLE'])['SOLD PRICE'].mean()
print(role)
# Out:
# AGE  PLAYING_ROLE
# 1    Allrounder      5.875000e+05
#      Batsman         1.110000e+06
#      Bowler          5.177143e+05
# 2    Allrounder      4.494000e+05
#      Batsman         6.547619e+05
#      Bowler          3.979310e+05
#      W. Keeper       4.677273e+05
# 3    Allrounder      7.666667e+05
#      Batsman         4.576923e+05
#      Bowler          4.143750e+05
#      W. Keeper       7.000000e+05
# Name: SOLD PRICE, dtype: float64

# %%
df[df['SIXERS']>80][['PLAYER NAME','SIXERS']]
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 28  Gilchrist, AC      86
# 82     Pathan, YK      81
# 88      Raina, SK      97
# 97     Sharma, RG      82

# %%
df[df['SIXERS']<80][['PLAYER NAME','SIXERS']]
# Out:
#       PLAYER NAME  SIXERS
# 0     Abdulla, YA       0
# 1    Abdur Razzak       0
# 2     Agarkar, AB       5
# 3       Ashwin, R       0
# 4    Badrinath, S      28
# ..            ...     ...
# 125     Yadav, AS       2
# 126   Younis Khan       0
# 127  Yuvraj Singh      67
# 128   Zaheer Khan       1
# 129    Zoysa, DNT       0
#
# [125 rows x 2 columns]

# %%
df[df['AGE']>1][['PLAYER NAME','AGE']]
# Out:
#       PLAYER NAME  AGE
# 0     Abdulla, YA    2
# 1    Abdur Razzak    2
# 2     Agarkar, AB    2
# 4    Badrinath, S    2
# 5      Bailey, GJ    2
# ..            ...  ...
# 125     Yadav, AS    2
# 126   Younis Khan    2
# 127  Yuvraj Singh    2
# 128   Zaheer Khan    2
# 129    Zoysa, DNT    2
#
# [114 rows x 2 columns]

# %%
df[df['AGE']>2][['PLAYER NAME','AGE']]
# Out:
#          PLAYER NAME  AGE
# 11    Chanderpaul, S    3
# 18        Dravid, RS    3
# 22       Fleming, SP    3
# 25       Ganguly, SC    3
# 27         Gibbs, HH    3
# 28     Gilchrist, AC    3
# 32        Hayden, ML    3
# 33      Henderson, T    3
# 35         Hodge, BJ    3
# 38       Hussey, MEK    3
# 41    Jayasuriya, ST    3
# 44        Kallis, JH    3
# 49        Katich, SM    3
# 52         Kumble, A    3
# 53    Langeveldt, CK    3
# 54       Laxman, VVS    3
# 62       McGrath, GD    3
# 63     Misbah-ul-Haq    3
# 69   Muralitharan, M    3
# 70        Nannes, DP    3
# 84       Pollock, SM    3
# 86       Ponting, RT    3
# 98     Shoaib Akhtar    3
# 107       Styris, SB    3
# 108       Symonds, A    3
# 111    Tendulkar, SR    3
# 117      Vaas, WPUJC    3
# 122        Warne, SK    3

# %%
df[df['WKTS']>60][['PLAYER NAME','WKTS']]
# Out:
#         PLAYER NAME  WKTS
# 12       Chawla, PP    73
# 57      Malinga, SL    83
# 64        Mishra, A    74
# 67       Morkel, JA    69
# 76         Ojha, PP    69
# 79        Patel, MM    70
# 81       Pathan, IK    66
# 101       Singh, RP    74
# 121  Vinay Kumar, R    61
# 128     Zaheer Khan    65

# %%
df[df['T_WKTS']>60][['PLAYER NAME','T_WKTS']]
# Out:
#          PLAYER NAME  T_WKTS
# 10         Bravo, DJ      86
# 20       Edwards, FH     157
# 21     Fernando, CRD      97
# 23       Flintoff, A     226
# 26         Gayle, CH      72
# 30   Harbhajan Singh     406
# 41    Jayasuriya, ST      98
# 44        Kallis, JH     276
# 52         Kumble, A     619
# 55            Lee, B     310
# 57       Malinga, SL     101
# 62       McGrath, GD     563
# 66     Mohammad Asif     106
# 68         Morkel, M     139
# 69   Muralitharan, M     800
# 74          Ntini, M     390
# 76          Ojha, PP      62
# 81        Pathan, IK     100
# 84       Pollock, SM     421
# 95         Sharma, I     133
# 98     Shoaib Akhtar     178
# 105     Sreesanth, S      87
# 106        Steyn, DW     272
# 115         Umar Gul     157
# 117      Vaas, WPUJC     355
# 120      Vettori, DL     359
# 122        Warne, SK     708
# 128      Zaheer Khan     288
# 129       Zoysa, DNT      64

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([0,7,2,6])
y=np.array([10,20,30,40])
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o:')
plt.show()

# %%
plt.plot(x,y,'D')
plt.show()

# %%
plt.plot(x,y,'d:')
plt.show()

# %%
plt.plot(x,y,'d--')
plt.show()

# %%
plt.plot(x,y,'o-.')
plt.show()

# %%
plt.plot(x,y,'o:g')
plt.show()

# %%
plt.plot(x,y,'o:b')
plt.show()

# %%
plt.plot(x,y,'o:g')
plt.show()

# %%
plt.plot(y,marker='o',ms=20)
plt.show()

# %%
plt.plot(x,y,linestyle='dotted')
plt.show()

# %%
plt.plot(x)
plt.plot(y)
plt.show()

# %%
plt.plot(x)
plt.plot(y)
plt.title('SHOW')
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([4,8,2,6])
plt.bar(x,y,color='red')
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([14,8,20,6])
plt.barh(x,y,color='red')
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([4,8,2,6])
plt.bar(x,y,color='red',width=0.1)
plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([4,8,2,6])
plt.barh(x,y,color='red',height=0.1)
plt.show()

# %%
import seaborn as sn
sage_df = sage.to_frame(name='SOLD PRICE')

sn.barplot(x='AGE',y='SOLD PRICE',data=sage_df)
plt.title("SHOW")
plt.show()

# %%
plt.hist(df['SOLD PRICE'])
plt.show()

# %%
plt.hist(df['SOLD PRICE'],bins=200)
plt.show()

# %%
sn.distplot(df['SOLD PRICE'],color='red')
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_9656\1062429370.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['SOLD PRICE'],color='red')

# %%
sn.distplot(df['SOLD PRICE'],color='green',bins=200)
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_9656\2249576207.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['SOLD PRICE'],color='green',bins=200)

# %%
x=np.array([1,5,7,9,3])
y=np.array([4,7,10,1,8])
plt.scatter(x,y)
plt.show()
