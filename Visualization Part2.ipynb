# %%
#subplot function takes 3 arguments describe the figure the layout describes the layout of the figure

# the layout us organized in rows and columns which are represented bby the first and second arguments.

# the thid arguments represent the the index of current plot


#Draw two plots using subplot() 

import matplotlib.pyplot as plt
import numpy as np
# Plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

#plot 2 
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
#Super title
# add a title for entire figure

import matplotlib.pyplot as plt
import numpy as np
# Plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

#plot 2 
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("Pattern of Sales and Income")

plt.show()

# %%
# We want to see the figure in column wise

import matplotlib.pyplot as plt
import numpy as np
# Plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.title("SALES")

#adding space between twon figure
plt.subplots_adjust(hspace=0.5)

#plot 2 
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("FIG 1")

#plot 2 
x=np.array([0,1,2,3])
y=np.array([5,8,12,3])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.title("FIG 2")

x=np.array([0,1,2,3])
y=np.array([1,9,5,10])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.title("FIG 3")
plt.subplots_adjust(hspace=0.5)

x=np.array([0,1,2,3])
y=np.array([6,10,7,11])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.title("FIG 4")

plt.subplots_adjust(hspace=0.5)
x=np.array([0,1,2,3])
y=np.array([10,8,1,9])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.title("FIG 5")
plt.subplots_adjust(hspace=0.5)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.title("FIG 6")

plt.suptitle("ALL 6 Figure")

plt.show()
